# %%
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

# %%
import requests

cookies = {
    '_d_id': '6d6e4f87-cf90-4bd3-acbd-abab61cb227b',
    'user_uuid': 'ff1a3e7a.8770.48be.b576.c1ab03356c57vpbFrWqi1P',
    'mynt-eupv': '1',
    'ru': 'OBxEOxAyeUAVT1BheUZzdQAwBQ9bRnJtI0pFX1xKGUFkB00IOTgXAEQhWA9SfUAwIzMzNDUzMDI1NTUkMg%3D%3D.aeb3a4dd2c62217bcf777371b24ee4f8',
    'mynt-ulc-api': 'pincode%3A110043',
    'x-mynt-pca': 'J1y41AJhBuqvny1AwGkMCFkD1N774FC9Ix9jO6bjhX5WaLx3x8qU_HDr2bodLvBWteoDUpHppkBojGiqc3fNp7pMWfJX8huMxj96JZq755qH75PE_tob_XljMATtBmDcqwbrH3NV6cNRfcZzgf6h-gvTuR71D4cr8tjAXZu8pzncfuwEVU9j94K43u5UibcXUbLQZ0FkQZprRXz8HL-Ki5fV3B6uvh9ZXg%3D%3D',
    'at': '...',
    'ak_bmsc': '8FFB8C2CE7838522C11AA074F282C305~000000000000000000000000000000~...',
    '_abck': 'D303301F9DE0AF2DE82AFF6553F23169~0~...~-1~-1~-1~AAQAAAAE%2f%2f%2f%2f%2f1H4IiPZKVVa%2frE3uZskeuzzHdJOyaRGoCmI6JMxf5ObiOsYCci60LhwXyO7gZikzuW+URHpgTQmTZxLEwhkWKJwvSuTvVMuK8qjX4zO9eDGAJEc9gZkhBPJeu7za5pIo6Y63d0%3d~-1',
    'bm_sz': '2B5A88FD16E834E35D8742A65C607790~...~4601397~3687238',
    '_xsrf': 'zodOydRPWZqOV5ZqMtRFdGD8DNkqBYIY',
    'mynt-loc-src': 'expiry%3A1768061632344%7Csource%3AIP',
    'utrid': 'Cl15GW9xQn8LSlt5BGFAMCMyNTc1NjU4MDg0JDI%3D.5b69554658b397f9482bd0e3e0ce5f15',
    'bm_mi': 'A7E205D6787DAB1CB84412BF6FF42A6A~~1',
    '_ma_session': '%7B%22id%22%3A%220e576cc6-8b25-4f06-a770-40acfb6877e7-6d6e4f87-cf90-4bd3-acbd-abab61cb227b%22%2C%22referrer_url%22%3A%22%22%2C%22utm_medium%22%3A%22%22%2C%22utm_source%22%3A%22%22%2C%22utm_channel%22%3A%22direct%22%7D',
    'bm_sv': '5406D16E35D65ED1C486B2637E3E46B8~~1',
}

headers = {
    'accept': 'application/json',
    'accept-language': 'en-US,en;q=0.6',
    'app': 'web',
    'content-type': 'application/json',
    'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMwNjIwNzEiLCJhcCI6IjcxODQwNzY0MyIsImlkIjoiNmEyY2QwNDQ4ZWJhNjQ3ZiIsInRyIjoiOWFhZmY3ODY0ZDgxYWMzY2Q0ZmQ0MWExY2VjMGEyNzQiLCJ0aSI6MTc2ODA2Njc1MTU3MSwidGsiOiI2Mjk1Mjg2In19',
    'pagination-context': '{"productRack":{"dsCnsdrd":0,"tp":"nonDS","cntCnsdrd":0,"slrCnsdrd":0},"scImgVideoOffset":"0_0","v":1.0,"productsRowsShown":25,"paginationCacheKey":"fcee4b27-94a1-407c-83ec-2245bce0ded4","inorganicRowsShown":3,"plaContext":"...","refresh":false,"inorganicWidgetsOffset":{"bannerAdsOffset":0,"missionsOffset":0,"inlineFiltersGroupOffset":2,"relatedSearchesOffset":0,"productRacksOffset":0,"recSearchOffset":0,"trOffset":{"trendsRackOffset":1,"atsaOffset":1,"socialOffset":10}},"scOffset":0,"reqId":"fcee4b27-94a1-407c-83ec-2245bce0ded4"}',
    'priority': 'u=1, i',
    'referer': 'https://www.myntra.com/dresses?sort=discount&f=Gender%3Amen%20women%2Cwomen',
    'sec-ch-ua': '"Brave";v="143", "Chromium";v="143", "Not A(Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Linux"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'sec-gpc': '1',
    'traceparent': '00-9aaff7864d81ac3cd4fd41a1cec0a274-6a2cd0448eba647f-01',
    'tracestate': '6295286@nr=0-1-3062071-718407643-6a2cd0448eba647f----1768066751571',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36',
    'x-location-context': 'pincode=110043;source=IP',
    'x-meta-app': 'channel=web',
    'x-myntra-app': 'deviceID=6d6e4f87-cf90-4bd3-acbd-abab61cb227b;customerID=;reqChannel=web;appFamily=MyntraRetailWeb;',
    'x-myntraweb': 'Yes',
    'x-requested-with': 'browser',
    # 'cookie': '_d_id=6d6e4f87-cf90-4bd3-acbd-abab61cb227b; user_uuid=ff1a3e7a.8770.48be.b576.c1ab03356c57vpbFrWqi1P; mynt-eupv=1; ru=OBxEOxAyeUAVT1BheUZzdQAwBQ9bRnJtI0pFX1xKGUFkB00IOTgXAEQhWA9SfUAwIzMzNDUzMDI1NTUkMg%3D%3D.aeb3a4dd2c62217bcf777371b24ee4f8; mynt-ulc-api=pincode%3A110043; x-mynt-pca=J1y41AJhBuqvny1AwGkMCFkD1N774FC9Ix9jO6bjhX5WaLx3x8qU_HDr2bodLvBWteoDUpHppkBojGiqc3fNp7pMWfJX8huMxj96JZq755qH75PE_tob_XljMATtBmDcqwbrH3NV6cNRfcZzgf6h-gvTuR71D4cr8tjAXZu8pzncfuwEVU9j94K43u5UibcXUbLQZ0FkQZprRXz8HL-Ki5fV3B6uvh9ZXg%3D%3D; at=...; ak_bmsc=8FFB8C2CE7838522C11AA074F282C305~000000000000000000000000000000~...; _abck=D303301F9DE0AF2DE82AFF6553F23169~0~...~-1~-1~-1~AAQAAAAE%2f%2f%2f%2f%2f1H4IiPZKVVa%2frE3uZskeuzzHdJOyaRGoCmI6JMxf5ObiOsYCci60LhwXyO7gZikzuW+URHpgTQmTZxLEwhkWKJwvSuTvVMuK8qjX4zO9eDGAJEc9gZkhBPJeu7za5pIo6Y63d0%3d~-1; bm_sz=2B5A88FD16E834E35D8742A65C607790~...~4601397~3687238; _xsrf=zodOydRPWZqOV5ZqMtRFdGD8DNkqBYIY; mynt-loc-src=expiry%3A1768061632344%7Csource%3AIP; utrid=Cl15GW9xQn8LSlt5BGFAMCMyNTc1NjU4MDg0JDI%3D.5b69554658b397f9482bd0e3e0ce5f15; bm_mi=A7E205D6787DAB1CB84412BF6FF42A6A~~1; _ma_session=%7B%22id%22%3A%220e576cc6-8b25-4f06-a770-40acfb6877e7-6d6e4f87-cf90-4bd3-acbd-abab61cb227b%22%2C%22referrer_url%22%3A%22%22%2C%22utm_medium%22%3A%22%22%2C%22utm_source%22%3A%22%22%2C%22utm_channel%22%3A%22direct%22%7D; bm_sv=5406D16E35D65ED1C486B2637E3E46B8~~1',
}

params = {
    'sort': 'discount',
    'f': 'Gender:men women,women',
    'rows': '50',
    'o': '49',
    'plaEnabled': 'true',
    'xdEnabled': 'false',
    'isFacet': 'true',
    'p': '2',
    'pincode': '110043',
}

response = requests.get('https://www.myntra.com/gateway/v4/search/dresses', params=params, cookies=cookies, headers=headers)

# %%
from datetime import date

data = response.json()
products = data.get("products", [])

snapshot_date = date.today().isoformat()
extracted_items = []

#loop through the products and extract features
for p in products:
    if not isinstance(p, dict):
        continue
    ALLOWED = {
        "Crazy_Deal",
        "Festive_Price_Crash",
        "GST_Benefit_Included",
        "Myntra_Unique"
        }

    tag_groups = p.get("styleTagEntry", {}).get("tagGroups", {})

    promotion_tags = [
        t["tagId"]
        for block in ("pricing", "selection")
        for t in tag_groups.get(block, {}).get("tagInfos", [])
        if t.get("tagId") in ALLOWED
        ]
    extracted_items.append({
        "product_id": p.get("productId"),
        "brand": p.get("brand"),
        "gender": p.get('gender'),
        "category": p.get("category"),
        "master_category": (p.get("masterCategory") or {}).get('typeName'),
        "su_cCategory": (p.get('subCategory') or {}).get('typeName'),
        "article_type": (p.get("articleType") or {}).get('typeName'),
        "mrp": p.get("mrp"),
        "price": p.get("price"),
        "discount": p.get("discount"),
        "discount_type": p.get("discountType"),
        "discount_display_label": p.get("discountDisplayLabel"),
        #"coupon_data" = p.get("couponData") or {},
        "coupon_discount" : (p.get("couponData") or {}).get("couponDiscount"),
        "best_price": ((p.get("couponData") or {}).get("couponDescription") or {}).get("bestPrice"),
        "rating": p.get("rating"),
        "rating_count": p.get("ratingCount"),
        "listViews": p.get("listViews"),
        "inventory": sum(i.get("inventory", 0) for i in p.get("inventoryInfo", [])),
        "available": any(i.get("available", False) for i in p.get("inventoryInfo", [])),
        "sizes": p.get("sizes"),
        "has_multiple_sizes": p.get("hasMultipleSizes"),
        "snapshot_date": snapshot_date,
        "season": p.get("season"),
        "is_fast_fashion": p.get("isFastFashion"),
        "promotion_tags": "|".join(promotion_tags),
        "has_promotion": bool(promotion_tags),
        "year": p.get('year'),
        "preferred_delivery_tag": p.get("preferredDeliveryTag"),
        "delivery_promise": p.get("deliveryPromise")
    })

# %%
dff = pd.DataFrame(extracted_items)
print(dff.shape)
dff.head()
# Out:
# (50, 29)
#    product_id              brand gender category master_category su_cCategory  \
# 0    31654574         Chandbaali  Women  Dresses         Apparel        Dress
# 1    34524170  Stylecast X Kotty  Women  Dresses         Apparel        Dress
# 2    29026834  Stylecast X Kotty  Women  Dresses         Apparel        Dress
# 3    28350448  Stylecast X Kotty  Women  Dresses         Apparel        Dress
# 4    27908966  Stylecast X Kotty  Women  Dresses         Apparel        Dress
#
#   article_type   mrp  price  discount discount_type discount_display_label  \
# 0      Dresses  6499    649      5850             1              (90% OFF)
# 1      Dresses  2999    299      2700             1              (90% OFF)
# 2      Dresses  2999    299      2700             1              (90% OFF)
# 3      Dresses  2999    299      2700             1              (90% OFF)
# 4      Dresses  2999    299      2700             1              (90% OFF)
#
#    coupon_discount  best_price    rating  rating_count  listViews  inventory  \
# 0              228         421  0.000000             0          0         15
# 1              150         149  3.633333            30          0        125
# 2              150         149  4.233333            30          0          9
# 3              150         149  0.000000             0          0         15
# 4              150         149  3.886364            44          0          1
#
#    available         sizes  has_multiple_sizes snapshot_date  season  \
# 0       True  S,M,L,XL,XXL                True    2026-01-10  Summer
# 1       True      S,M,L,XL                True    2026-01-10  Summer
# 2       True      S,M,L,XL                True    2026-01-10  Summer
# 3       True      S,M,L,XL                True    2026-01-10  Summer
# 4       True      S,M,L,XL                True    2026-01-10  Summer
#
#    is_fast_fashion                                promotion_tags  \
# 0            False
# 1             True  Crazy_Deal|Festive_Price_Crash|Myntra_Unique
# 2             True                                 Myntra_Unique
# 3            False                                 Myntra_Unique
# 4             True                                 Myntra_Unique
#
#    has_promotion  year preferred_delivery_tag    delivery_promise
# 0          False  2025
# 1           True  2025                EXPRESS  Delivery By Jan 11
# 2           True  2024                EXPRESS  Delivery By Jan 12
# 3           True  2024                EXPRESS  Delivery By Jan 11
# 4           True  2024                EXPRESS  Delivery By Jan 12

# %%
#Concatenate new page data to old page data
import os

FILE_PATH = '/home/manju/projects/m8.csv'

if os.path.exists(FILE_PATH):
    old_df = pd.read_csv(FILE_PATH)
    final_df = pd.concat([old_df, dff], ignore_index=True)
else:
    final_df = dff

final_df.to_csv(FILE_PATH, index=False)

print("Total rows so far:", final_df.shape[0])
# Out:
# Total rows so far: 799

# %%
df = pd.read_csv('/home/manju/projects/m8.csv')

df['product_id'].nunique()
# Out:
# 747

# %%
#Chceck no. of unique products
final_df['product_id'].nunique()
# Out:
# 747

# %%
#Concatenat discount, popular and recommended products
df_disc = pd.read_csv('/home/manju/projects/day1_disc.csv')
df_pop = pd.read_csv('/home/manju/projects/day1_pop.csv')
df_reco = pd.read_csv('/home/manju/projects/day1_rec.csv')

#adding sort column
df_reco["source_sort"] = "recommended"
df_pop["source_sort"] = "popularity"
df_disc["source_sort"] = "discount"

df_day_raw = pd.concat([df_pop, df_reco, df_disc], ignore_index=True)
print(df_day_raw.shape)
df_day_raw.head()
# Out:
# (2433, 31)
#    Unnamed: 0  product_id            brand gender category master_category  \
# 0         NaN    29615058           TANDUL  Women  Dresses         Apparel
# 1         NaN    25497076                W  Women  Dresses         Apparel
# 2         NaN    20911328  Berrylush Curve  Women  Dresses         Apparel
# 3         NaN    36145538          Tzelynn  Women  Dresses         Apparel
# 4         NaN    30663177        Berrylush  Women  Dresses         Apparel
#
#   su_cCategory article_type   mrp  price  discount  discount_type  \
# 0        Dress      Dresses  1499    577       922            1.0
# 1        Dress      Dresses  4599   2299      2300            1.0
# 2        Dress      Dresses  3499   1084      2415            1.0
# 3        Dress      Dresses  1499    899       600            1.0
# 4        Dress      Dresses  2799    727      2072            1.0
#
#   discount_display_label  coupon_discount  best_price    rating  rating_count  \
# 0          (Rs. 922 OFF)            202.0       375.0  3.964602           339
# 1              (50% OFF)            500.0      1799.0  4.298387           372
# 2              (69% OFF)            350.0       734.0  4.291102          4428
# 3              (40% OFF)            315.0       584.0  3.896552            29
# 4              (74% OFF)            255.0       472.0  4.055147           272
#
#    listViews  inventory  available                sizes  has_multiple_sizes  \
# 0          0          1       True             S,M,L,XL                True
# 1          0        173       True  XS,S,M,M/L,L,XL,XXL                True
# 2          0         26       True  XXL,3XL,4XL,5XL,6XL                True
# 3          0        968       True             S,M,L,XL                True
# 4          0         45       True          XS,S,M,L,XL                True
#
#   snapshot_date  season  is_fast_fashion                  promotion_tags  \
# 0    2026-01-10  Summer             True             Festive_Price_Crash
# 1    2026-01-10    Fall             True  Festive_Price_Crash|Crazy_Deal
# 2    2026-01-10  Summer             True             Festive_Price_Crash
# 3    2026-01-10  Summer             True                             NaN
# 4    2026-01-10  Summer             True  Crazy_Deal|Festive_Price_Crash
#
#    has_promotion  year preferred_delivery_tag    delivery_promise source_sort
# 0           True  2024                EXPRESS  Delivery By Jan 12  popularity
# 1           True  2023                EXPRESS  Delivery By Jan 12  popularity
# 2           True  2025                EXPRESS  Delivery By Jan 12  popularity
# 3          False  2025                    NaN                 NaN  popularity
# 4           True  2025                EXPRESS  Delivery By Jan 12  popularity

# %%
#drop_duplicates
df_day = df_day_raw.drop_duplicates(subset=['product_id', 'snapshot_date'])
print(df_day.shape)
df_day.head()
# Out:
# (2006, 31)
#    Unnamed: 0  product_id            brand gender category master_category  \
# 0         NaN    29615058           TANDUL  Women  Dresses         Apparel
# 1         NaN    25497076                W  Women  Dresses         Apparel
# 2         NaN    20911328  Berrylush Curve  Women  Dresses         Apparel
# 3         NaN    36145538          Tzelynn  Women  Dresses         Apparel
# 4         NaN    30663177        Berrylush  Women  Dresses         Apparel
#
#   su_cCategory article_type   mrp  price  discount  discount_type  \
# 0        Dress      Dresses  1499    577       922            1.0
# 1        Dress      Dresses  4599   2299      2300            1.0
# 2        Dress      Dresses  3499   1084      2415            1.0
# 3        Dress      Dresses  1499    899       600            1.0
# 4        Dress      Dresses  2799    727      2072            1.0
#
#   discount_display_label  coupon_discount  best_price    rating  rating_count  \
# 0          (Rs. 922 OFF)            202.0       375.0  3.964602           339
# 1              (50% OFF)            500.0      1799.0  4.298387           372
# 2              (69% OFF)            350.0       734.0  4.291102          4428
# 3              (40% OFF)            315.0       584.0  3.896552            29
# 4              (74% OFF)            255.0       472.0  4.055147           272
#
#    listViews  inventory  available                sizes  has_multiple_sizes  \
# 0          0          1       True             S,M,L,XL                True
# 1          0        173       True  XS,S,M,M/L,L,XL,XXL                True
# 2          0         26       True  XXL,3XL,4XL,5XL,6XL                True
# 3          0        968       True             S,M,L,XL                True
# 4          0         45       True          XS,S,M,L,XL                True
#
#   snapshot_date  season  is_fast_fashion                  promotion_tags  \
# 0    2026-01-10  Summer             True             Festive_Price_Crash
# 1    2026-01-10    Fall             True  Festive_Price_Crash|Crazy_Deal
# 2    2026-01-10  Summer             True             Festive_Price_Crash
# 3    2026-01-10  Summer             True                             NaN
# 4    2026-01-10  Summer             True  Crazy_Deal|Festive_Price_Crash
#
#    has_promotion  year preferred_delivery_tag    delivery_promise source_sort
# 0           True  2024                EXPRESS  Delivery By Jan 12  popularity
# 1           True  2023                EXPRESS  Delivery By Jan 12  popularity
# 2           True  2025                EXPRESS  Delivery By Jan 12  popularity
# 3          False  2025                    NaN                 NaN  popularity
# 4           True  2025                EXPRESS  Delivery By Jan 12  popularity

# %%
df_day.to_csv('day1_data.csv')
