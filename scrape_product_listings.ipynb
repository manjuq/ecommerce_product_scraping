# %%
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

# %%
import pandas as pd

# %% [markdown]
# ## Discount-Driven Demand vs Customer Trust: Pricing Strategy Analysis in a Fashion Marketplace

# %%
import requests

cookies = {
    '_d_id': '6d6e4f87-cf90-4bd3-acbd-abab61cb227b',
    'user_uuid': 'ff1a3e7a.8770.48be.b576.c1ab03356c57vpbFrWqi1P',
    'mynt-eupv': '1',
    'ru': 'OBxEOxAyeUAVT1BheUZzdQAwBQ9bRnJtI0pFX1xKGUFkB00IOTgXAEQhWA9SfUAwIzMzNDUzMDI1NTUkMg%3D%3D.aeb3a4dd2c62217bcf777371b24ee4f8',
    'mynt-ulc-api': 'pincode%3A110043',
    'x-mynt-pca': 'J1y41AJhBuqvny1AwGkMCFkD1N774FC9Ix9jO6bjhX5WaLx3x8qU_HDr2bodLvBWteoDUpHppkBojGiqc3fNp7pMWfJX8huMxj96JZq755qH75PE_tob_XljMATtBmDcqwbrH3NV6cNRfcZzgf6h-gvTuR71D4cr8tjAXZu8pzncfuwEVU9j94K43u5UibcXUbLQZ0FkQZprRXz8HL-Ki5fV3B6uvh9ZXg%3D%3D',
    'at': '...',
    '_ma_session': '%7B%22id%22%3A%22f2592df3-b597-4e42-837a-5c87ddf35cca-6d6e4f87-cf90-4bd3-acbd-abab61cb227b%22%2C%22referrer_url%22%3A%22%22%2C%22utm_medium%22%3A%22%22%2C%22utm_source%22%3A%22%22%2C%22utm_channel%22%3A%22direct%22%7D',
    'ak_bmsc': '8FFB8C2CE7838522C11AA074F282C305~000000000000000000000000000000~...',
    '_abck': 'D303301F9DE0AF2DE82AFF6553F23169~0~...~-1~-1~-1~AAQAAAAE%2f%2f%2f%2f%2f1H4IiPZKVVa%2frE3uZskeuzzHdJOyaRGoCmI6JMxf5ObiOsYCci60LhwXyO7gZikzuW+URHpgTQmTZxLEwhkWKJwvSuTvVMuK8qjX4zO9eDGAJEc9gZkhBPJeu7za5pIo6Y63d0%3d~-1',
    'bm_sz': '2B5A88FD16E834E35D8742A65C607790~...~4601397~3687238',
    '_xsrf': 'zodOydRPWZqOV5ZqMtRFdGD8DNkqBYIY',
    'mynt-loc-src': 'expiry%3A1768061632344%7Csource%3AIP',
    'utrid': 'Cl15GW9xQn8LSlt5BGFAMCMyNTc1NjU4MDg0JDI%3D.5b69554658b397f9482bd0e3e0ce5f15',
    'bm_mi': 'A7E205D6787DAB1CB84412BF6FF42A6A~~1',
    'bm_sv': '5406D16E35D65ED1C486B2637E3E46B8~~1',
}

headers = {
    'accept': 'application/json',
    'accept-language': 'en-US,en;q=0.6',
    'app': 'web',
    'content-type': 'application/json',
    'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMwNjIwNzEiLCJhcCI6IjcxODQwNzY0MyIsImlkIjoiNThlZmE1MTg3OTY4YTgzZSIsInRyIjoiMjVmYjBhY2VhZWVhZmMzM2E0ZGMxZDFhMmU2YWM3ZmUiLCJ0aSI6MTc2ODA2Mzg5NzU0NywidGsiOiI2Mjk1Mjg2In19',
    'pagination-context': '{"productRack":{"dsCnsdrd":0,"tp":"nonDS","cntCnsdrd":0,"slrCnsdrd":0},"scImgVideoOffset":"0_0","v":1.0,"productsRowsShown":475,"paginationCacheKey":"45c1f255-7afc-4929-85eb-503a1aade899","inorganicRowsShown":6,"plaContext":"...\\u003d","refresh":false,"inorganicWidgetsOffset":{"bannerAdsOffset":0,"missionsOffset":0,"inlineFiltersGroupOffset":4,"relatedSearchesOffset":0,"productRacksOffset":0,"recSearchOffset":0,"trOffset":{"trendsRackOffset":2,"atsaOffset":10,"socialOffset":10}},"scOffset":0,"reqId":"45c1f255-7afc-4929-85eb-503a1aade899"}',
    'priority': 'u=1, i',
    'referer': 'https://www.myntra.com/dresses?f=Gender%3Amen%20women%2Cwomen',
    'sec-ch-ua': '"Brave";v="143", "Chromium";v="143", "Not A(Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Linux"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'sec-gpc': '1',
    'traceparent': '00-25fb0aceaeeafc33a4dc1d1a2e6ac7fe-58efa5187968a83e-01',
    'tracestate': '6295286@nr=0-1-3062071-718407643-58efa5187968a83e----1768063897547',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36',
    'x-location-context': 'pincode=110043;source=IP',
    'x-meta-app': 'channel=web',
    'x-myntra-app': 'deviceID=6d6e4f87-cf90-4bd3-acbd-abab61cb227b;customerID=;reqChannel=web;appFamily=MyntraRetailWeb;',
    'x-myntraweb': 'Yes',
    'x-requested-with': 'browser',
    # 'cookie': '_d_id=6d6e4f87-cf90-4bd3-acbd-abab61cb227b; user_uuid=ff1a3e7a.8770.48be.b576.c1ab03356c57vpbFrWqi1P; mynt-eupv=1; ru=OBxEOxAyeUAVT1BheUZzdQAwBQ9bRnJtI0pFX1xKGUFkB00IOTgXAEQhWA9SfUAwIzMzNDUzMDI1NTUkMg%3D%3D.aeb3a4dd2c62217bcf777371b24ee4f8; mynt-ulc-api=pincode%3A110043; x-mynt-pca=J1y41AJhBuqvny1AwGkMCFkD1N774FC9Ix9jO6bjhX5WaLx3x8qU_HDr2bodLvBWteoDUpHppkBojGiqc3fNp7pMWfJX8huMxj96JZq755qH75PE_tob_XljMATtBmDcqwbrH3NV6cNRfcZzgf6h-gvTuR71D4cr8tjAXZu8pzncfuwEVU9j94K43u5UibcXUbLQZ0FkQZprRXz8HL-Ki5fV3B6uvh9ZXg%3D%3D; at=...; _ma_session=%7B%22id%22%3A%22f2592df3-b597-4e42-837a-5c87ddf35cca-6d6e4f87-cf90-4bd3-acbd-abab61cb227b%22%2C%22referrer_url%22%3A%22%22%2C%22utm_medium%22%3A%22%22%2C%22utm_source%22%3A%22%22%2C%22utm_channel%22%3A%22direct%22%7D; ak_bmsc=8FFB8C2CE7838522C11AA074F282C305~000000000000000000000000000000~...; _abck=D303301F9DE0AF2DE82AFF6553F23169~0~...~-1~-1~-1~AAQAAAAE%2f%2f%2f%2f%2f1H4IiPZKVVa%2frE3uZskeuzzHdJOyaRGoCmI6JMxf5ObiOsYCci60LhwXyO7gZikzuW+URHpgTQmTZxLEwhkWKJwvSuTvVMuK8qjX4zO9eDGAJEc9gZkhBPJeu7za5pIo6Y63d0%3d~-1; bm_sz=2B5A88FD16E834E35D8742A65C607790~...~4601397~3687238; _xsrf=zodOydRPWZqOV5ZqMtRFdGD8DNkqBYIY; mynt-loc-src=expiry%3A1768061632344%7Csource%3AIP; utrid=Cl15GW9xQn8LSlt5BGFAMCMyNTc1NjU4MDg0JDI%3D.5b69554658b397f9482bd0e3e0ce5f15; bm_mi=A7E205D6787DAB1CB84412BF6FF42A6A~~1; bm_sv=5406D16E35D65ED1C486B2637E3E46B8~~1',
}

params = {
    'f': 'Gender:men women,women',
    'rows': '50',
    'o': '949',
    'plaEnabled': 'true',
    'xdEnabled': 'false',
    'isFacet': 'true',
    'p': '20',
    'pincode': '110043',
}

response = requests.get('https://www.myntra.com/gateway/v4/search/dresses', params=params, cookies=cookies, headers=headers)

# %%
from datetime import date

data = response.json()
products = data.get("products", [])

#print(f"Page {page} | Offset {offset} | Products {len(products)}")
snapshot_date = date.today().isoformat()
extracted_items = []

for p in products:
    if not isinstance(p, dict):
        continue
    ALLOWED = {
        "Crazy_Deal",
        "Festive_Price_Crash",
        "GST_Benefit_Included",
        "Myntra_Unique"
        }

    tag_groups = p.get("styleTagEntry", {}).get("tagGroups", {})

    promotion_tags = [
        t["tagId"]
        for block in ("pricing", "selection")
        for t in tag_groups.get(block, {}).get("tagInfos", [])
        if t.get("tagId") in ALLOWED
        ]
    extracted_items.append({
        "product_id": p.get("productId"),
        "brand": p.get("brand"),
        "gender": p.get('gender'),
        "category": p.get("category"),
        "master_category": (p.get("masterCategory") or {}).get('typeName'),
        "su_cCategory": (p.get('subCategory') or {}).get('typeName'),
        "article_type": (p.get("articleType") or {}).get('typeName'),
        "mrp": p.get("mrp"),
        "price": p.get("price"),
        "discount": p.get("discount"),
        "discount_type": p.get("discountType"),
        "discount_display_label": p.get("discountDisplayLabel"),
        #"coupon_data" = p.get("couponData") or {},
        "coupon_discount" : (p.get("couponData") or {}).get("couponDiscount"),
        "best_price": ((p.get("couponData") or {}).get("couponDescription") or {}).get("bestPrice"),
        "rating": p.get("rating"),
        "rating_count": p.get("ratingCount"),
        "listViews": p.get("listViews"),
        "inventory": sum(i.get("inventory", 0) for i in p.get("inventoryInfo", [])),
        "available": any(i.get("available", False) for i in p.get("inventoryInfo", [])),
        "sizes": p.get("sizes"),
        "has_multiple_sizes": p.get("hasMultipleSizes"),
        "snapshot_date": snapshot_date,
        "season": p.get("season"),
        "is_fast_fashion": p.get("isFastFashion"),
        "promotion_tags": "|".join(promotion_tags),
        "has_promotion": bool(promotion_tags),
        "year": p.get('year'),
        "preferred_delivery_tag": p.get("preferredDeliveryTag"),
        "delivery_promise": p.get("deliveryPromise")
    })

# %%
dff = pd.DataFrame(extracted_items)
print(dff.shape)
dff.head()
# Out:
# (33, 29)
#    product_id            brand gender category master_category su_cCategory  \
# 0    38263873              H&M  Women  Dresses         Apparel        Dress
# 1    29908096  Marks & Spencer  Women  Dresses         Apparel        Dress
# 2    39052511              R&B  Women  Dresses         Apparel        Dress
# 3    31386499        StyleCast  Women  Dresses         Apparel        Dress
# 4    37224276             bebe  Women  Dresses         Apparel        Dress
#
#   article_type   mrp  price  discount discount_type discount_display_label  \
# 0      Dresses  2999   2999         0             1
# 1      Dresses  3999   1599      2400             1              (60% OFF)
# 2      Dresses  1699   1699         0
# 3      Dresses  3449   1517      1932             1              (56% OFF)
# 4      Dresses  8699   4001      4698             1              (54% OFF)
#
#    coupon_discount  best_price    rating  rating_count  listViews  inventory  \
# ...

# %% [markdown]
# new try

# %%
import os

FILE_PATH = '/home/manju/projects/m8.csv'

if os.path.exists(FILE_PATH):
    old_df = pd.read_csv(FILE_PATH)
    final_df = pd.concat([old_df, dff], ignore_index=True)
else:
    final_df = dff

final_df.to_csv(FILE_PATH, index=False)

print("Total rows so far:", final_df.shape[0])
# Out:
# Total rows so far: 466
