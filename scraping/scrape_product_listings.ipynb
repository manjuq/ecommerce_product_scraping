# %%
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

# %%
import requests

cookies = {
    '_d_id': '6d6e4f87-cf90-4bd3-acbd-abab61cb227b',
    'user_uuid': 'ff1a3e7a.8770.48be.b576.c1ab03356c57vpbFrWqi1P',
    'mynt-eupv': '1',
    'ru': 'OBxEOxAyeUAVT1BheUZzdQAwBQ9bRnJtI0pFX1xKGUFkB00IOTgXAEQhWA9SfUAwIzMzNDUzMDI1NTUkMg%3D%3D.aeb3a4dd2c62217bcf777371b24ee4f8',
    'at': '...',
    '_abck': 'D303301F9DE0AF2DE82AFF6553F23169~0~...~-1~-1~-1~AAQAAAAF%2f%2f%2f%2f%2f1SeOa%2fFc%2feQzdxeydAzmHwhLAP53S3Hbhh4+4HlmYoe%2fdiY21JeHYGSzTFLvxZGLaXJdJbuiJieIRUrbsNcNfFfUtLzGVMQS7ZkCLcq0EtGLHBP7VStdI6snMbxl6Fi27gxJwg%3d~-1',
    'bm_sz': '1E29F25A87A3E72AB85F8B9FF1D79DE9~...~3621687~4274489',
    'ak_bmsc': '543C4E4CFE2D6D5978590C4BE9ECC66A~000000000000000000000000000000~...',
    '_mxab_': 'config.bucket%3Dregular%3Bcoupon.cart.channelAware%3DchannelAware_Enabled%3Bcart.cartfiller.personalised%3Denabled',
    'microsessid': '17',
    'lt_timeout': '1',
    'lt_session': '1',
    '_xsrf': 'F3myWa3vx3z5wSsYYK4wASPNtzhRyt6g',
    'user_session': 'etb2ASgy1_4wvY5lASUwBA.eMZKF1RGtI01S2KP0aRN3sCcfU9rBvwT7MwJhBaIFAvu6PxqLhcgo-LTBh_A6HlV5GQgG99rcljqwKAUY-hvc7bkMG5gYlO3CADpIFlLlVo3gKmInJ9V4fhNJ8GiGUTBueHn6tT9ateoTN0cBZsS7Q.1768363334236.86400000.qhpNwqf3Ph3swXJlE-rCA3FcMbNPvX0wSvmINvCMpBw',
    '_ma_session': '%7B%22id%22%3A%222d40d773-f97a-42bb-8749-150a39bd39e6-6d6e4f87-cf90-4bd3-acbd-abab61cb227b%22%2C%22referrer_url%22%3A%22%22%2C%22utm_medium%22%3A%22%22%2C%22utm_source%22%3A%22%22%2C%22utm_channel%22%3A%22direct%22%7D',
    'mynt-ulc-api': 'pincode%3A110020',
    'mynt-loc-src': 'expiry%3A1768364773582%7Csource%3AIP',
    'x-mynt-pca': 'i6mlirKqBgTsrwykV6Uh79916MdeUXK8gOtgeAFhCh51AZWHkgLyV9j1GTWf0X2YWuM5Sunellvuofw9j6v0TbpViWa9rtnVPFuaDi_-yTdDSmWqXmLUSIPE0y2j3pk0DYrViOk7LUbrr-g0CTkwknMa4alF3NjJJKELLXugv7lGuSsNGgk4KR-sGYLisrSn-tc%3D',
    'bm_mi': '7D8A742E80083CEFE1F4FFBD335F0F3C~~1',
    'utrid': 'DGd9SVhfeR4UTVUPYElAMCMzNzE5OTU4ODI4JDI%3D.14de0138499404f409238fe48f43d48e',
    'bm_sv': 'BF3AC1DB7EA9C66AF09CED2449B7CD39~~1',
}

headers = {
    'accept': 'application/json',
    'accept-language': 'en-US,en;q=0.6',
    'app': 'web',
    'content-type': 'application/json',
    'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMwNjIwNzEiLCJhcCI6IjcxODQwNzY0MyIsImlkIjoiOTFhZDgwMWM3MGUyNTlmOSIsInRyIjoiNGJkOWQ4MGIyMTUxMjU3YjI2NjQ3ZjNhY2Q0NGEzZmYiLCJ0aSI6MTc2ODM2Mzc4MjQzOSwidGsiOiI2Mjk1Mjg2In19',
    'pagination-context': '{"refresh":true,"v":1}',
    'priority': 'u=1, i',
    'referer': 'https://www.myntra.com/dresses?sort=popularity&f=Gender%3Amen%20women%2Cwomen',
    'sec-ch-ua': '"Brave";v="143", "Chromium";v="143", "Not A(Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Linux"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'sec-gpc': '1',
    'traceparent': '00-4bd9d80b2151257b26647f3acd44a3ff-91ad801c70e259f9-01',
    'tracestate': '6295286@nr=0-1-3062071-718407643-91ad801c70e259f9----1768363782439',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36',
    'x-location-context': 'pincode=110020;source=IP',
    'x-meta-app': 'channel=web',
    'x-myntra-app': 'deviceID=6d6e4f87-cf90-4bd3-acbd-abab61cb227b;customerID=;reqChannel=web;appFamily=MyntraRetailWeb;',
    'x-myntraweb': 'Yes',
    'x-requested-with': 'browser',
    # 'cookie': '_d_id=6d6e4f87-cf90-4bd3-acbd-abab61cb227b; user_uuid=ff1a3e7a.8770.48be.b576.c1ab03356c57vpbFrWqi1P; mynt-eupv=1; ru=OBxEOxAyeUAVT1BheUZzdQAwBQ9bRnJtI0pFX1xKGUFkB00IOTgXAEQhWA9SfUAwIzMzNDUzMDI1NTUkMg%3D%3D.aeb3a4dd2c62217bcf777371b24ee4f8; at=...; _abck=D303301F9DE0AF2DE82AFF6553F23169~0~...~-1~-1~-1~AAQAAAAF%2f%2f%2f%2f%2f1SeOa%2fFc%2feQzdxeydAzmHwhLAP53S3Hbhh4+4HlmYoe%2fdiY21JeHYGSzTFLvxZGLaXJdJbuiJieIRUrbsNcNfFfUtLzGVMQS7ZkCLcq0EtGLHBP7VStdI6snMbxl6Fi27gxJwg%3d~-1; bm_sz=1E29F25A87A3E72AB85F8B9FF1D79DE9~...~3621687~4274489; ak_bmsc=543C4E4CFE2D6D5978590C4BE9ECC66A~000000000000000000000000000000~...; _mxab_=config.bucket%3Dregular%3Bcoupon.cart.channelAware%3DchannelAware_Enabled%3Bcart.cartfiller.personalised%3Denabled; microsessid=17; lt_timeout=1; lt_session=1; _xsrf=F3myWa3vx3z5wSsYYK4wASPNtzhRyt6g; user_session=etb2ASgy1_4wvY5lASUwBA.eMZKF1RGtI01S2KP0aRN3sCcfU9rBvwT7MwJhBaIFAvu6PxqLhcgo-LTBh_A6HlV5GQgG99rcljqwKAUY-hvc7bkMG5gYlO3CADpIFlLlVo3gKmInJ9V4fhNJ8GiGUTBueHn6tT9ateoTN0cBZsS7Q.1768363334236.86400000.qhpNwqf3Ph3swXJlE-rCA3FcMbNPvX0wSvmINvCMpBw; _ma_session=%7B%22id%22%3A%222d40d773-f97a-42bb-8749-150a39bd39e6-6d6e4f87-cf90-4bd3-acbd-abab61cb227b%22%2C%22referrer_url%22%3A%22%22%2C%22utm_medium%22%3A%22%22%2C%22utm_source%22%3A%22%22%2C%22utm_channel%22%3A%22direct%22%7D; mynt-ulc-api=pincode%3A110020; mynt-loc-src=expiry%3A1768364773582%7Csource%3AIP; x-mynt-pca=i6mlirKqBgTsrwykV6Uh79916MdeUXK8gOtgeAFhCh51AZWHkgLyV9j1GTWf0X2YWuM5Sunellvuofw9j6v0TbpViWa9rtnVPFuaDi_-yTdDSmWqXmLUSIPE0y2j3pk0DYrViOk7LUbrr-g0CTkwknMa4alF3NjJJKELLXugv7lGuSsNGgk4KR-sGYLisrSn-tc%3D; bm_mi=7D8A742E80083CEFE1F4FFBD335F0F3C~~1; utrid=DGd9SVhfeR4UTVUPYElAMCMzNzE5OTU4ODI4JDI%3D.14de0138499404f409238fe48f43d48e; bm_sv=BF3AC1DB7EA9C66AF09CED2449B7CD39~~1',
}

params = {
    'sort': 'popularity',
    'f': 'Gender:men women,women',
    'rows': '50',
    'o': '0',
    'plaEnabled': 'true',
    'xdEnabled': 'false',
    'isFacet': 'true',
    'p': '1',
    'pincode': '110020',
}

response = requests.get('https://www.myntra.com/gateway/v4/search/dresses', params=params, cookies=cookies, headers=headers)

# %%
from datetime import date

data = response.json()
products = data.get("products", [])

snapshot_date = date.today().isoformat()
extracted_items = []

#loop through the products and extract features
for p in products:
    if not isinstance(p, dict):
        continue
    ALLOWED = {
        "Crazy_Deal",
        "Festive_Price_Crash",
        "GST_Benefit_Included",
        "Myntra_Unique"
        }

    tag_groups = p.get("styleTagEntry", {}).get("tagGroups", {})

    promotion_tags = [
        t["tagId"]
        for block in ("pricing", "selection")
        for t in tag_groups.get(block, {}).get("tagInfos", [])
        if t.get("tagId") in ALLOWED
        ]
    extracted_items.append({
        "product_id": p.get("productId"),
        "brand": p.get("brand"),
        "gender": p.get('gender'),
        "category": p.get("category"),
        "master_category": (p.get("masterCategory") or {}).get('typeName'),
        "su_cCategory": (p.get('subCategory') or {}).get('typeName'),
        "article_type": (p.get("articleType") or {}).get('typeName'),
        "mrp": p.get("mrp"),
        "price": p.get("price"),
        "discount": p.get("discount"),
        "discount_type": p.get("discountType"),
        "discount_display_label": p.get("discountDisplayLabel"),
        #"coupon_data" = p.get("couponData") or {},
        "coupon_discount" : (p.get("couponData") or {}).get("couponDiscount"),
        "best_price": ((p.get("couponData") or {}).get("couponDescription") or {}).get("bestPrice"),
        "rating": p.get("rating"),
        "rating_count": p.get("ratingCount"),
        "listViews": p.get("listViews"),
        "inventory": sum(i.get("inventory", 0) for i in p.get("inventoryInfo", [])),
        "available": any(i.get("available", False) for i in p.get("inventoryInfo", [])),
        "sizes": p.get("sizes"),
        "has_multiple_sizes": p.get("hasMultipleSizes"),
        "snapshot_date": snapshot_date,
        "season": p.get("season"),
        "is_fast_fashion": p.get("isFastFashion"),
        "promotion_tags": "|".join(promotion_tags),
        "has_promotion": bool(promotion_tags),
        "year": p.get('year'),
        "preferred_delivery_tag": p.get("preferredDeliveryTag"),
        "delivery_promise": p.get("deliveryPromise")
    })

# %%
dff = pd.DataFrame(extracted_items)
print(dff.shape)
dff.tail()
# Out:
# (50, 29)
#     product_id                brand gender category master_category  \
# 45    37974488        SHYAM SUNDARI  Women  Dresses         Apparel
# 46    38336271               ZUMMER  Women  Dresses         Apparel
# 47    36744225  StyleCast x Revolte  Women  Dresses         Apparel
# 48    36393980                 PIMU  Women  Dresses         Apparel
# 49    36643604              Antheaa  Women  Dresses         Apparel
#
#    su_cCategory article_type   mrp  price  discount  ...             sizes  \
# 45        Dress      Dresses  1659    459      1200  ...          S,M,L,XL
# 46        Dress      Dresses  3299   1299      2000  ...      S,M,L,XL,XXL
# 47        Dress      Dresses  3999   1239      2760  ...  S,M,L,XL,XXL,3XL
# 48        Dress      Dresses  2999    449      2550  ...  S,M,L,XL,XXL,3XL
# 49        Dress      Dresses  3299   1880      1419  ...   XS,S,M,L,XL,XXL
#
#    has_multiple_sizes  snapshot_date  season  is_fast_fashion  promotion_tags  \
# ...

# %%
#Concatenate new page data to old page data
import os

FILE_PATH = '/home/manju/projects/m8.csv'

if os.path.exists(FILE_PATH):
    old_df = pd.read_csv(FILE_PATH)
    final_df = pd.concat([old_df, dff], ignore_index=True)
else:
    final_df = dff

final_df.to_csv(FILE_PATH, index=False)

print("Total rows so far:", final_df.shape[0])
# Out:
# Total rows so far: 999

# %%
#Concatenate discount, popular and recommended products file for every day
day = "day4"
df_disc = pd.read_csv(f'data/{day}_disc.csv')
df_pop = pd.read_csv(f'data/{day}_pop.csv')
df_reco = pd.read_csv(f'data/{day}_rec.csv')

#adding sort column
df_reco["source_sort"] = "recommended"
df_pop["source_sort"] = "popularity"
df_disc["source_sort"] = "discount"

df_day_raw = pd.concat([df_pop, df_reco, df_disc], ignore_index=True)
print(df_day_raw.shape)
df_day_raw.head()

# %%
#drop_duplicates
df_day = df_day_raw.drop_duplicates(subset=['product_id', 'snapshot_date'])
print(df_day.shape)
df_day.head()

# %%
#store in csv file
df_day.to_csv(f'data/{day}_data.csv')
