# %%
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

# %%
import requests

cookies = {
    '_d_id': '6d6e4f87-cf90-4bd3-acbd-abab61cb227b',
    'user_uuid': 'ff1a3e7a.8770.48be.b576.c1ab03356c57vpbFrWqi1P',
    'mynt-eupv': '1',
    'ru': 'OBxEOxAyeUAVT1BheUZzdQAwBQ9bRnJtI0pFX1xKGUFkB00IOTgXAEQhWA9SfUAwIzMzNDUzMDI1NTUkMg%3D%3D.aeb3a4dd2c62217bcf777371b24ee4f8',
    'at': '...',
    'mynt-ulc-api': 'pincode%3A110043',
    'x-mynt-pca': 'G6nb6ohBWNo5BrUgSx-KIkZKo18v6izxtMkJIm3PDfsgVpzR6VR5Icf9nmgCFForz_nAEwa3y0HdLrMops8yau--BdjW77Wax3osLww4OnqIjdJjiA1_Ki5IFt_o6U9hv17ocEGbG-eRKFHi04GfCqS-9anqFZxKBvD-grKYTbcQuIWiQgebKqTOOlgAYjvkPMM%3D',
    '_ma_session': '%7B%22id%22%3A%22e6001813-386f-435c-9fa3-32cfc92498b1-6d6e4f87-cf90-4bd3-acbd-abab61cb227b%22%2C%22referrer_url%22%3A%22%22%2C%22utm_medium%22%3A%22%22%2C%22utm_source%22%3A%22%22%2C%22utm_channel%22%3A%22direct%22%7D',
    '_mxab_': 'config.bucket%3Dregular%3Bcoupon.cart.channelAware%3DchannelAware_Enabled%3Bcart.cartfiller.personalised%3Denabled',
    '_pv': 'default',
    'dp': 'd',
    'lt_timeout': '1',
    'lt_session': '1',
    'bm_sz': '05FC5A2D3BB0D21B178329ED0A17FBD9~~3753269~3682626',
    '_abck': 'D303301F9DE0AF2DE82AFF6553F23169~0~...~-1~-1~-1~AAQAAAAF%2f%2f%2f%2f%2f11U676F4DUfSdUBasPeI4uKlVpM0yEuUXM2P6RXvVEA9qinVur9Ij%2f1B+QXouaHGBjUmMGSah9lSZwb7moOKEjPVbfczG+Ub9xElodmYXVwtlmvEKonAHI2gloL23IGP+LN5qA%3d~-1',
    'microsessid': '379',
    '_xsrf': 'm57orDlzyKCyUn7Evxlzb8BDepZ32WYy',
    'mynt-loc-src': 'expiry%3A1768718192959%7Csource%3AIP',
    'ak_bmsc': 'C9094D9A82FE0478CFD652DD040E8CEB~000000000000000000000000000000~...',
    'utm_track_v1': '%7B%22utm_source%22%3A%22direct%22%2C%22utm_medium%22%3A%22direct%22%2C%22trackstart%22%3A1768716817%2C%22trackend%22%3A1768716877%7D',
    'user_session': 'ziX-szIMmcDF-TZmsjcndA.Jt81X5nELXFSAwcMT9M05cySkzOJYwxS_89aXvIuhGhYKWBlPKuUwKperH-grW48NsMucXjp9h0dArstLx0TVXFKhIS5Vwp2-u1LUhiihZJOKbFu43NwQgMKc3erDc_UUO9HRok3lCDcjYrjx_vb8A.1768716752228.86400000.i-kH20aVKOIGScX8ybwriQZPjFo5_4Lb-SUcPj9OIB8',
    'utrid': 'FEdBXl0LCA16FnlVdUFAMCM3MDI4MzE2MDYkMg%3D%3D.73eb9703b94f8d0bc8f390d83ab2e02d',
    'bm_sv': '1E6D9110A765667906BD0E9B0479E16F~~1',
}

headers = {
    'accept': 'application/json',
    'accept-language': 'en-US,en;q=0.6',
    'app': 'web',
    'content-type': 'application/json',
    'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMwNjIwNzEiLCJhcCI6IjcxODQwNzY0MyIsImlkIjoiNDZjMDQ1NjgyMzRiZjI3ZSIsInRyIjoiNTdiODNmNTUxY2JkNzA2NmIyYWNkNTgxYTgyMzFiN2EiLCJ0aSI6MTc2ODcxNjgyNTY1MywidGsiOiI2Mjk1Mjg2In19',
    'pagination-context': '{"refresh":true,"v":1}',
    'priority': 'u=1, i',
    'referer': 'https://www.myntra.com/dresses?sort=discount&f=Gender%3Amen%20women%2Cwomen',
    'sec-ch-ua': '"Not(A:Brand";v="8", "Chromium";v="144", "Brave";v="144"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Linux"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'sec-gpc': '1',
    'traceparent': '00-57b83f551cbd7066b2acd581a8231b7a-46c04568234bf27e-01',
    'tracestate': '6295286@nr=0-1-3062071-718407643-46c04568234bf27e----1768716825653',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36',
    'x-location-context': 'pincode=110043;source=IP',
    'x-meta-app': 'channel=web',
    'x-myntra-app': 'deviceID=6d6e4f87-cf90-4bd3-acbd-abab61cb227b;customerID=;reqChannel=web;appFamily=MyntraRetailWeb;',
    'x-myntraweb': 'Yes',
    'x-requested-with': 'browser',
    # 'cookie': '_d_id=6d6e4f87-cf90-4bd3-acbd-abab61cb227b; user_uuid=ff1a3e7a.8770.48be.b576.c1ab03356c57vpbFrWqi1P; mynt-eupv=1; ru=OBxEOxAyeUAVT1BheUZzdQAwBQ9bRnJtI0pFX1xKGUFkB00IOTgXAEQhWA9SfUAwIzMzNDUzMDI1NTUkMg%3D%3D.aeb3a4dd2c62217bcf777371b24ee4f8; at=...; mynt-ulc-api=pincode%3A110043; x-mynt-pca=G6nb6ohBWNo5BrUgSx-KIkZKo18v6izxtMkJIm3PDfsgVpzR6VR5Icf9nmgCFForz_nAEwa3y0HdLrMops8yau--BdjW77Wax3osLww4OnqIjdJjiA1_Ki5IFt_o6U9hv17ocEGbG-eRKFHi04GfCqS-9anqFZxKBvD-grKYTbcQuIWiQgebKqTOOlgAYjvkPMM%3D; _ma_session=%7B%22id%22%3A%22e6001813-386f-435c-9fa3-32cfc92498b1-6d6e4f87-cf90-4bd3-acbd-abab61cb227b%22%2C%22referrer_url%22%3A%22%22%2C%22utm_medium%22%3A%22%22%2C%22utm_source%22%3A%22%22%2C%22utm_channel%22%3A%22direct%22%7D; _mxab_=config.bucket%3Dregular%3Bcoupon.cart.channelAware%3DchannelAware_Enabled%3Bcart.cartfiller.personalised%3Denabled; _pv=default; dp=d; lt_timeout=1; lt_session=1; bm_sz=05FC5A2D3BB0D21B178329ED0A17FBD9~~3753269~3682626; _abck=D303301F9DE0AF2DE82AFF6553F23169~0~...~-1~-1~-1~AAQAAAAF%2f%2f%2f%2f%2f11U676F4DUfSdUBasPeI4uKlVpM0yEuUXM2P6RXvVEA9qinVur9Ij%2f1B+QXouaHGBjUmMGSah9lSZwb7moOKEjPVbfczG+Ub9xElodmYXVwtlmvEKonAHI2gloL23IGP+LN5qA%3d~-1; microsessid=379; _xsrf=m57orDlzyKCyUn7Evxlzb8BDepZ32WYy; mynt-loc-src=expiry%3A1768718192959%7Csource%3AIP; ak_bmsc=C9094D9A82FE0478CFD652DD040E8CEB~000000000000000000000000000000~...; utm_track_v1=%7B%22utm_source%22%3A%22direct%22%2C%22utm_medium%22%3A%22direct%22%2C%22trackstart%22%3A1768716817%2C%22trackend%22%3A1768716877%7D; user_session=ziX-szIMmcDF-TZmsjcndA.Jt81X5nELXFSAwcMT9M05cySkzOJYwxS_89aXvIuhGhYKWBlPKuUwKperH-grW48NsMucXjp9h0dArstLx0TVXFKhIS5Vwp2-u1LUhiihZJOKbFu43NwQgMKc3erDc_UUO9HRok3lCDcjYrjx_vb8A.1768716752228.86400000.i-kH20aVKOIGScX8ybwriQZPjFo5_4Lb-SUcPj9OIB8; utrid=FEdBXl0LCA16FnlVdUFAMCM3MDI4MzE2MDYkMg%3D%3D.73eb9703b94f8d0bc8f390d83ab2e02d; bm_sv=1E6D9110A765667906BD0E9B0479E16F~~1',
}

params = {
    'sort': 'discount',
    'f': 'Gender:men women,women',
    'rows': '50',
    'o': '0',
    'plaEnabled': 'true',
    'xdEnabled': 'false',
    'isFacet': 'true',
    'p': '1',
    'pincode': '110043',
}

response = requests.get('https://www.myntra.com/gateway/v4/search/dresses', params=params, cookies=cookies, headers=headers)

# %%
from datetime import date

data = response.json()
products = data.get("products", [])

snapshot_date = date.today().isoformat()
extracted_items = []

#loop through the products and extract features
for p in products:
    if not isinstance(p, dict):
        continue
    ALLOWED = {
        "Crazy_Deal",
        "Festive_Price_Crash",
        "GST_Benefit_Included",
        "Myntra_Unique"
        }

    tag_groups = p.get("styleTagEntry", {}).get("tagGroups", {})

    promotion_tags = [
        t["tagId"]
        for block in ("pricing", "selection")
        for t in tag_groups.get(block, {}).get("tagInfos", [])
        if t.get("tagId") in ALLOWED
        ]
    extracted_items.append({
        "product_id": p.get("productId"),
        "brand": p.get("brand"),
        "gender": p.get('gender'),
        "category": p.get("category"),
        "master_category": (p.get("masterCategory") or {}).get('typeName'),
        "sub_category": (p.get('subCategory') or {}).get('typeName'),
        "article_type": (p.get("articleType") or {}).get('typeName'),
        "mrp": p.get("mrp"),
        "price": p.get("price"),
        "discount": p.get("discount"),
        "discount_type": p.get("discountType"),
        "discount_display_label": p.get("discountDisplayLabel"),
        #"coupon_data" = p.get("couponData") or {},
        "coupon_discount" : (p.get("couponData") or {}).get("couponDiscount"),
        "best_price": ((p.get("couponData") or {}).get("couponDescription") or {}).get("bestPrice"),
        "rating": p.get("rating"),
        "rating_count": p.get("ratingCount"),
        "list_views": p.get("listViews"),
        "inventory": sum(i.get("inventory", 0) for i in p.get("inventoryInfo", [])),
        "available": any(i.get("available", False) for i in p.get("inventoryInfo", [])),
        "sizes": p.get("sizes"),
        "has_multiple_sizes": p.get("hasMultipleSizes"),
        "snapshot_date": snapshot_date,
        "season": p.get("season"),
        "is_fast_fashion": p.get("isFastFashion"),
        "promotion_tags": "|".join(promotion_tags),
        "has_promotion": bool(promotion_tags),
        "year": p.get('year'),
        "preferred_delivery_tag": p.get("preferredDeliveryTag"),
        "delivery_promise": p.get("deliveryPromise"),
        "source_sort":"discount"
    })

# %%
dff = pd.DataFrame(extracted_items)
print(dff.shape)
dff.tail()
# Out:
# (50, 30)
#     product_id  brand gender category master_category sub_category  \
# 45    17956016  plusS  Women  Dresses         Apparel        Dress
# 46    16587814  plusS  Women  Dresses         Apparel        Dress
# 47    17500806  plusS  Women  Dresses         Apparel        Dress
# 48    13914214  plusS  Women  Dresses         Apparel        Dress
# 49    13526268  plusS  Women  Dresses         Apparel        Dress
#
#    article_type   mrp  price  discount discount_type discount_display_label  \
# 45      Dresses  2799    280      2519             1              (90% OFF)
# 46      Dresses  2799    280      2519             1              (90% OFF)
# 47      Dresses  2499    250      2249             1              (90% OFF)
# 48      Dresses  2299    230      2069             1              (90% OFF)
# 49      Dresses  2199    220      1979             1              (90% OFF)
#
#     coupon_discount  best_price    rating  rating_count  list_views  \
# ...

# %%
#Concatenate new page data to old page data
import os
day = 'day_07'

FILE_PATH = f'/home/manju/projects/ecommerce_product_scraping/data/raw/{day}.csv'

if os.path.exists(FILE_PATH):
    old_df = pd.read_csv(FILE_PATH)
    final_df = pd.concat([old_df, dff], ignore_index=True)
else:
    final_df = dff

final_df.to_csv(FILE_PATH, index=False)

print("Total rows so far:", final_df.shape[0])
# Out:
# Total rows so far: 2997

# %%
# #Concatenate discount, popular and recommended products file for every day
# day = "day5"
# df_disc = pd.read_csv(f'../data/raw/{day}_disc.csv')
# df_pop = pd.read_csv(f'../data/raw/{day}_pop.csv')
# df_reco = pd.read_csv(f'../data/raw/{day}_rec.csv')

# #adding sort column
# df_reco["source_sort"] = "recommended"
# df_pop["source_sort"] = "popularity"
# df_disc["source_sort"] = "discount"

# df_day_raw = pd.concat([df_pop, df_reco, df_disc], ignore_index=True)
# print(df_day_raw.shape)
# df_day_raw.head()

# %%
# #drop_duplicates
# df_day = df_day_raw.drop_duplicates(subset=['product_id', 'snapshot_date'])
# print(df_day.shape)
# df_day.head()

# %%
# #store in csv file
# day = "day_06"
# df_day_raw.to_csv(f'../data/raw/{day}.csv')
